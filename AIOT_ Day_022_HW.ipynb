# %% [markdown]
# # 作業1 :
# ##### 請問我們要使用 ArgumentParser 的哪一個方法來新增一個參數?

# %% [markdown]
# #### Ans: add_argument()

# %%
from IPython.display import Image
Image("/Users/lochien-min/Desktop/截圖 2021-04-06 下午1.40.28.png",width=500,height=500)

# %% [markdown]
# # 作業2
# ##### 在使用YOLO的推論程序darknet detector test時，我們需要指定那些參數?

# %%
Image("/Users/lochien-min/Downloads/1601095557939.png",width=500,height=500)
