# %% [markdown]
# # 作業一:

# %% [markdown]
# ### Raspios桌面版解壓縮後大小為:6.85G
# ### Raspios文字版解壓縮後大小為:1.71G

# %%
from IPython.display import Image
Image("/Users/lochien-min/Desktop/截圖 2021-03-19 下午4.06.55.png",width=400,height=400)
