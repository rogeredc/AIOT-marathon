# %% [markdown]
# # 作業1

# %% [markdown]
# ### 將映像檔alpine下載至電腦

# %%
from IPython.display import Image
Image("/Users/lochien-min/Desktop/截圖 2021-03-22 上午9.55.08.png",width=400,height=400)

# %% [markdown]
# # 作業2

# %% [markdown]
# ### 使用下載的映像檔建立容器，並選定本機中的一個資料夾與容器中的資料夾做連結，在本機與容器做連結的資料夾裡建立一個檔案，使用指令進到容器內，查看與外部連結的資料夾，即可看到剛剛在本機建立的檔案

# %%
Image("//Users/lochien-min/Desktop/截圖 2021-03-22 上午11.09.39.png",width=400,height=400)
