# %% [markdown]
# # 作業一

# %% [markdown]
# ##### 實作只接受 Get 發送的 Request，帶入參數 name，將其值回傳。

# %%
# 引用需要的套件, 若有多個套件要引用，可使用逗號隔開
from flask import Flask, request

app = Flask(__name__)

# 設定網址路由，及接受的 method(預設是 GET)
@app.route('/', methods=['GET'])
def index():
    name = request.args.get('name') # 取得 name 參數
    return "Hello " + name
    

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# 127.0.0.1 - - [24/Mar/2021 13:11:31] "GET /?name=roger HTTP/1.1" 200 -

# %%
from IPython.display import Image
Image("/Users/lochien-min/Desktop/截圖 2021-03-24 下午1.11.39.png",width=400,height=400)

# %% [markdown]
# # 作業二

# %% [markdown]
# ##### 實作只接受 Post 發送的 Request，帶入參數 name，將其值回傳。

# %%
# 引用需要的套件, 若有多個套件要引用，可使用逗號隔開
from flask import Flask, request

app = Flask(__name__)

# 設定網址路由，及接受的 method(預設是 GET)
@app.route('/', methods=['POST'])
def index():
    name = request.form.get('name') # 取得 name 參數
    passwd = request.form.get('passwd') # 取得 passwd 參數
    return "Your name: " + name + ", Your passwd: " + passwd
    

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# 127.0.0.1 - - [24/Mar/2021 13:14:08] "GET / HTTP/1.1" 405 -
# 127.0.0.1 - - [24/Mar/2021 13:15:27] "POST / HTTP/1.1" 200 -

# %%
Image("/Users/lochien-min/Desktop/截圖 2021-03-24 下午1.15.50.png",width=400,height=400)

# %% [markdown]
# # 作業三

# %% [markdown]
# ##### 使用 Post 實作檔案上傳功能，並有一個簡單的畫面可以操作檔案上傳的動作。

# %%
# 引用需要的套件, 若有多個套件要引用，可使用逗號隔開
from flask import Flask, request

app = Flask(__name__)

# 設定網址路由，及接受的 method(預設是 GET)
@app.route('/', methods=['POST'])
def index():
    file = request.files['file'] # 取得 request 中的 file(記得發送 postman 中的 檔案參數名稱要和這邊一致)
    file.save(file.filename) # 把檔案存起來，並用原來的檔名作為名稱
    
    return file.filename # 回傳檔案名稱
    

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
